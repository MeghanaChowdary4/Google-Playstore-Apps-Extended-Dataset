# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaChowdary4/Google-Playstore-Apps-Extended-Dataset/blob/main/PROJECT_1_GOOGLE_PLAY_STORE_APPS_EXTENDED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GOOGLE PLAYSTORE APPS EXTENDED
#
# ### Although Google Play acts as a digital media store as well, the data covers only mobile applications.
#
# ### The Play Store apps data has enormous potential todrive app-making businesses to success.
# ### Actionableinsights can be drawn for developers to work on andcapture the Android market.
# ### The app market isgrowing with a dynamic speed and is ever changing.
#
# ### The Google Play Store is the largest and most popular Android app store.
#
# ### We collected descriptive information on over 3,100 apps across 11 different categories in the Google App Store.
# ### We focused on the following 11 categories: Business, Food & Drink, Books & Reference, Travel & Local, Health & Fitness,News & Magazines, Education, Social, Finance, Medical, and Entertainment.
#
# ### Each app has its own web page where detailed information about the app is available.
# ### We used Selenium to scrape information about each of these apps for our analysis.
# ### We scraped app title, category, developer name, whether an app contains ads, rating, number of reviews,app size, number of installs, and price.

# %%
#importing pandas library
import pandas as pd
#importing numoy library
import numpy as np

# %%
#importing csv file extended_googleplaystore

df = pd.read_csv("/content/drive/MyDrive/extended_googleplaystore.csv")
df
# Out:
#                                                     App  Category  Rating  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       0.0     4.1
# 1                                   Coloring book moana       0.0     3.9
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       0.0     4.7
# 3                                 Sketch - Draw & Paint       0.0     4.5
# 4                 Pixel Draw - Number Art Coloring Book       0.0     4.3
# ...                                                 ...       ...     ...
# 9654                                   Sya9a Maroc - FR      11.0     4.5
# 9655                   Fr. Mike Schmitz Audio Teachings      11.0     5.0
# 9656                             Parkinson Exercices FR      20.0     NaN
# 9657                      The SCP Foundation DB fr nn5n       3.0     4.5
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology      18.0     4.5
#
#       Reviews  Size    Installs  Type  Price Content Rating  Genres  ...  \
# ...

# %%
#previewing first 5 rows of the data

df.head()
# Out:
#                                                  App  Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook       0.0     4.1
# 1                                Coloring book moana       0.0     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...       0.0     4.7
# 3                              Sketch - Draw & Paint       0.0     4.5
# 4              Pixel Draw - Number Art Coloring Book       0.0     4.3
#
#    Reviews  Size    Installs  Type  Price Content Rating  Genres  ...  \
# 0      159  19.0     10000.0   0.0    0.0       Everyone     9.0  ...
# 1      967  14.0    500000.0   0.0    0.0       Everyone    12.0  ...
# 2    87510   8.7   5000000.0   0.0    0.0       Everyone     9.0  ...
# 3   215644  25.0  50000000.0   0.0    0.0           Teen     9.0  ...
# 4      967   2.8    100000.0   0.0    0.0       Everyone    11.0  ...
#
#   Last Updated (Year)  Last Updated (Year/Month)  Category (categorical)  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#viewing last 5 rows of the data

df.tail()
# Out:
#                                                 App  Category  Rating  \
# 9654                               Sya9a Maroc - FR      11.0     4.5
# 9655               Fr. Mike Schmitz Audio Teachings      11.0     5.0
# 9656                         Parkinson Exercices FR      20.0     NaN
# 9657                  The SCP Foundation DB fr nn5n       3.0     4.5
# 9658  iHoroscope - 2018 Daily Horoscope & Astrology      18.0     4.5
#
#       Reviews  Size    Installs  Type  Price Content Rating  Genres  ...  \
# 9654       38  53.0      5000.0   0.0    0.0       Everyone    38.0  ...
# 9655        4   3.6       100.0   0.0    0.0       Everyone    38.0  ...
# 9656        3   9.5      1000.0   0.0    0.0       Everyone    70.0  ...
# 9657      114   NaN      1000.0   0.0    0.0     Mature 17+    19.0  ...
# 9658   398307  19.0  10000000.0   0.0    0.0       Everyone    66.0  ...
#
#      Last Updated (Year)  Last Updated (Year/Month)  Category (categorical)  \
# ...

# %%
#checking the shape of the data

numberofrows_1, numberofcolumns_1 = df.shape
print('There are {} rows and {} columns'.format(numberofrows_1, numberofcolumns_1)+' in our Dataset.')
# Out:
# There are 9659 rows and 23 columns in our Dataset.

# %%
#Information about the datatypes and columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 23 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   App                                      9659 non-null   object
#  1   Category                                 9659 non-null   float64
#  2   Rating                                   8196 non-null   float64
#  3   Reviews                                  9659 non-null   int64
#  4   Size                                     8432 non-null   float64
#  5   Installs                                 9659 non-null   float64
#  6   Type                                     9659 non-null   float64
#  7   Price                                    9659 non-null   float64
#  8   Content Rating                           9659 non-null   object
#  9   Genres                                   9659 non-null   float64
# ...

# %%
#Generating descriptive statistics for overview

df.describe()
# Out:
#           Category       Rating       Reviews         Size      Installs  \
# count  9659.000000  8196.000000  9.659000e+03  8432.000000  9.659000e+03
# mean     16.760120     4.173243  2.165926e+05    20.395289  7.777507e+06
# std       8.400732     0.536625  1.831320e+06    21.827542  5.375828e+07
# min       0.000000     1.000000  0.000000e+00     0.008500  0.000000e+00
# 25%      11.000000     4.000000  2.500000e+01     4.600000  1.000000e+03
# 50%      14.000000     4.300000  9.670000e+02    12.000000  1.000000e+05
# 75%      25.000000     4.500000  2.940100e+04    28.000000  1.000000e+06
# max      32.000000     5.000000  7.815831e+07   100.000000  1.000000e+09
#
#               Type        Price       Genres  Current Ver  Android Ver  \
# count  9659.000000  9659.000000  9659.000000  9659.000000  9659.000000
# mean      0.078165     1.099299    63.777720  1204.159954    16.945232
# std       0.268831    16.852152    32.352326   925.247113     6.966001
# ...

# %%
#Listing all the column names in the dataset

df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Last Updated (Year)', 'Last Updated (Year/Month)',
#        'Category (categorical)', 'Type (categorical)', 'Genres (categorical)',
#        'Current Ver (categorical)', 'Android Ver (categorical)',
#        'Last Updated (Year/Month) (categorical)', 'No_reviews_count',
#        'Reviews_present_count'],
#       dtype='object')

# %%
#visualizing the null values in the dataset

df.isnull()
# Out:
#         App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0     False     False   False    False  False     False  False  False
# 1     False     False   False    False  False     False  False  False
# 2     False     False   False    False  False     False  False  False
# 3     False     False   False    False  False     False  False  False
# 4     False     False   False    False  False     False  False  False
# ...     ...       ...     ...      ...    ...       ...    ...    ...
# 9654  False     False   False    False  False     False  False  False
# 9655  False     False   False    False  False     False  False  False
# 9656  False     False    True    False  False     False  False  False
# 9657  False     False   False    False   True     False  False  False
# 9658  False     False   False    False  False     False  False  False
#
#       Content Rating  Genres  ...  Last Updated (Year)  \
# 0              False   False  ...                False
# ...

# %%
#Finding the number of null values in each column

df.isnull().sum()
# Out:
# App                                           0
# Category                                      0
# Rating                                     1463
# Reviews                                       0
# Size                                       1227
# Installs                                      0
# Type                                          0
# Price                                         0
# Content Rating                                0
# Genres                                        0
# Last Updated                                  0
# Current Ver                                   0
# Android Ver                                   0
# Last Updated (Year)                           0
# Last Updated (Year/Month)                     0
# Category (categorical)                        0
# Type (categorical)                            1
# Genres (categorical)                          0
# Current Ver (categorical)                     8
# Android Ver (categorical)                     2
# ...

# %%
df.describe(include="all")
# Out:
#                                                    App     Category  \
# count                                             9659  9659.000000
# unique                                            9659          NaN
# top     Photo Editor & Candy Camera & Grid & ScrapBook          NaN
# freq                                                 1          NaN
# mean                                               NaN    16.760120
# std                                                NaN     8.400732
# min                                                NaN     0.000000
# 25%                                                NaN    11.000000
# 50%                                                NaN    14.000000
# 75%                                                NaN    25.000000
# max                                                NaN    32.000000
#
#              Rating       Reviews         Size      Installs         Type  \
# count   8196.000000  9.659000e+03  8432.000000  9.659000e+03  9659.000000
# ...

# %%
#Finding the maximum number of rows in the dataset

print(pd.options.display.max_rows)
# Out:
# 60

# %%
modeis = df.Size.mode()

# %%
print(modeis)
# Out:
# 0    11.0
# dtype: float64

# %%
#Replacing false values with the mode

df.Size.fillna(modeis,inplace = False)
# Out:
# 0       19.0
# 1       14.0
# 2        8.7
# 3       25.0
# 4        2.8
#         ...
# 9654    53.0
# 9655     3.6
# 9656     9.5
# 9657     NaN
# 9658    19.0
# Name: Size, Length: 9659, dtype: float64

# %%
# Generate count statistics of duplicate entries

if (len(df[df.duplicated()]) > 0):
    print('No. of duplicated entries: ', len(df[df.duplicated()]))
    print(df[df.duplicated(keep = False)].sort_values(by = list(df.columns)).head())
else:
    print('No duplicated entries found.')
# Out:
# No duplicated entries found.

# %%
#Finding the duplicate values in the dataset

# %%
#Unique values of all features

df.nunique().to_frame(name ='Unique Values')
# Out:
#                                          Unique Values
# App                                               9659
# Category                                            33
# Rating                                              39
# Reviews                                           5330
# Size                                               459
# Installs                                            20
# Type                                                 3
# Price                                               92
# Content Rating                                       6
# Genres                                             118
# Last Updated                                      1377
# Current Ver                                       2818
# Android Ver                                         34
# Last Updated (Year)                                  9
# Last Updated (Year/Month)                           88
# Category (categorical)                              33
# ...

# %%
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
df['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %%
df['Installs'].nunique()
# Out:
# 20

# %%
df.value_counts()
# Out:
# App                                                      Category  Rating  Reviews  Size  Installs   Type  Price  Content Rating  Genres  Last Updated  Current Ver  Android Ver  Last Updated (Year)  Last Updated (Year/Month)  Category (categorical)  Type (categorical)  Genres (categorical)  Current Ver (categorical)  Android Ver (categorical)  Last Updated (Year/Month) (categorical)  No_reviews_count  Reviews_present_count
# +Download 4 Instagram Twitter                            27.0      4.5     40467    22.0  1000000.0  0.0   0.00   Everyone        100.0   2018-08-02    2174.0       17.0         2018                 87.0                       SOCIAL                  Free                Social                5.03                       4.1 and up                 2018-08                                  0                 0                        1
# ...

# %% [markdown]
# Summary Statistics

# %%
#importing seaborn library
import seaborn as sns
#importing matplot library
import matplotlib.pyplot as plt

# %%
graph=df.isnull().sum().plot.bar()    
plt.show()

# %%
print(df.groupby("No_reviews_count")["Reviews"].count())
df.groupby("Reviews_present_count")["Reviews"].count()
# Out:
# No_reviews_count
# 0      8722
# 1        67
# 2        56
# 3        44
# 4        49
#        ...
# 176       1
# 180       1
# 191       1
# 200       2
# 240       1
# Name: Reviews, Length: 95, dtype: int64
# Reviews_present_count
# 0      8843
# 1        23
# 2        13
# 3        16
# 4        12
#        ...
# 222       1
# 240       2
# 254       1
# 273       2
# 312       1
# Name: Reviews, Length: 131, dtype: int64

# %%
df.groupby("No_reviews_count")["Reviews_present_count"].count()
# Out:
# No_reviews_count
# 0      8722
# 1        67
# 2        56
# 3        44
# 4        49
#        ...
# 176       1
# 180       1
# 191       1
# 200       2
# 240       1
# Name: Reviews_present_count, Length: 95, dtype: int64

# %%
plt.title("Category Distribution of the Apps")
df.groupby("Category")["Type"].count().plot.pie(autopct="%1.1f%%",explode=None)
plt.show()

# %%
### Summary Statistics ###
df_summary = df[['App','Installs','Reviews','Reviews_present_count']]
df_summary.describe().transpose()
# Out:
#                         count          mean           std  min     25%  \
# Installs               9659.0  7.777507e+06  5.375828e+07  0.0  1000.0
# Reviews                9659.0  2.165926e+05  1.831320e+06  0.0    25.0
# Reviews_present_count  9659.0  3.719743e+00  1.646327e+01  0.0     0.0
#
#                             50%        75%           max
# Installs               100000.0  1000000.0  1.000000e+09
# Reviews                   967.0    29401.0  7.815831e+07
# Reviews_present_count       0.0        0.0  3.120000e+02

# %%
sns.distplot(df["Genres"],bins = "auto")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["Size"],bins = "auto")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["Current Ver"],bins = "auto")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df["Android Ver"],bins = "auto")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# sns.countplot(df["Sub-Category"],palette = 'nipy_spectral')
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","blue","black","gray","cyan","magenta"])  # as we know that 17 sub-category so 17 values for colors
df.groupby("Category")["Rating"].count().plot.bar(color=colors)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.head(2)
# Out:
#                                               App  Category  Rating  Reviews  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook       0.0     4.1      159
# 1                             Coloring book moana       0.0     3.9      967
#
#    Size  Installs  Type  Price Content Rating  Genres  ...  \
# 0  19.0   10000.0   0.0    0.0       Everyone     9.0  ...
# 1  14.0  500000.0   0.0    0.0       Everyone    12.0  ...
#
#   Last Updated (Year)  Last Updated (Year/Month)  Category (categorical)  \
# 0                2018                       80.0          ART_AND_DESIGN
# 1                2018                       80.0          ART_AND_DESIGN
#
#    Type (categorical)       Genres (categorical) Current Ver (categorical)  \
# 0                Free               Art & Design                     1.0.0
# 1                Free  Art & Design;Pretend Play                     2.0.0
#
#   Android Ver (categorical) Last Updated (Year/Month) (categorical)  \
# ...

# %%
plt.xticks(rotation=45, ha='right')
sns.countplot(df["Type"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.heatmap(df[["Current Ver","Android Ver","Last Updated (Year/Month)","No_reviews_count","Reviews_present_count"]].corr(), annot=True, cmap="CMRmap_r")
plt.show()

# %%
sns.violinplot(y='Rating',data=df,color="salmon")

# %%
sns.distplot(df['Rating'],bins=16,color='salmon')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.describe().T
# Out:
#                             count          mean           std        min  \
# Category                   9659.0  1.676012e+01  8.400732e+00     0.0000
# Rating                     8196.0  4.173243e+00  5.366247e-01     1.0000
# Reviews                    9659.0  2.165926e+05  1.831320e+06     0.0000
# Size                       8432.0  2.039529e+01  2.182754e+01     0.0085
# Installs                   9659.0  7.777507e+06  5.375828e+07     0.0000
# Type                       9659.0  7.816544e-02  2.688311e-01    -1.0000
# Price                      9659.0  1.099299e+00  1.685215e+01     0.0000
# Genres                     9659.0  6.377772e+01  3.235233e+01     0.0000
# Current Ver                9659.0  1.204160e+03  9.252471e+02    -1.0000
# Android Ver                9659.0  1.694523e+01  6.966001e+00    -1.0000
# Last Updated (Year)        9659.0  2.017346e+03  1.137600e+00  2010.0000
# Last Updated (Year/Month)  9659.0  7.752055e+01  1.332941e+01     0.0000
# ...
